# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"/Users/akanksha_rajput/Documents/ml/homework-1-Akanksha1Raj/task2/Oregon.csv")
print(df.dtypes)
df
# Out:
# year               int64
# marriage_rate    float64
# money_movie      float64
# dtype: object
#    year  marriage_rate  money_movie
# 0  2000            7.6          8.6
# 1  2001            7.5          9.0
# 2  2002            7.1          9.6
# 3  2003            7.2          9.9
# 4  2004            8.1          9.9
# 5  2005            7.3          9.1
# 6  2006            7.3          9.4
# 7  2007            7.2          9.6
# 8  2008            6.9          9.7
# 9  2009            6.6         10.4

# %%
df['year']
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2003
# 4    2004
# 5    2005
# 6    2006
# 7    2007
# 8    2008
# 9    2009
# Name: year, dtype: int64

# %%
ax1 = plt.gca()
line1, = ax1.plot(df["year"], df["marriage_rate"])
ax2 = ax1.twinx()
line2, = ax2.plot(df["year"], df["money_movie"], c='r')
ax1.set_ylabel("Marriage rate in Oregon")
ax2.set_ylabel("Money spent on movie theater admission")
ax2.legend((line1, line2),
           ("Marriage rate in Oregon", "Money spent on movie theater admission"))
