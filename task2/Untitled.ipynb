# %%
import os

#print(os.getcwd())
os.chdir("/Users/akanksha_rajput/Documents/ml/homework-1-Akanksha1Raj/task1")
print(os.getcwd())
# Out:
# /Users/akanksha_rajput/Documents/ml/homework-1-Akanksha1Raj/task1

# %%
import pandas as pd

df = pd.read_csv("input.txt",  encoding = "utf-16be", escapechar="\\")
print(df)
# Out:
#                          year       1980       1981       1982       1983  \
# 0                  افغانستان     15.0436   13.67368   12.57743   12.43058
# 1                  Shqipëria     2.67141    2.72427     2.7801    2.83732
# 2                    ⴷⵣⴰⵢⴻⵔ\n   18.80606   19.40704   20.03375   20.68098
# 3              American Samoa    0.03242     0.0336    0.03471    0.03584
# 4                      Angola    6.74308    6.87957    7.01853    7.24054
# 5                  Antarctica        NaN        NaN        NaN        NaN
# 6         Antigua and Barbuda    0.06855    0.06826    0.06801    0.06562
# 7                   Argentina    28.3698   28.84806   29.32988   29.79355
# 8                  Hayastán\n         --         --         --         --
# 9                       Aruba         --         --         --         --
# 10                 Australia     14.6159   14.92326   15.16178   15.34807
# 11                 Österreich    7.54943    7.56463    7.57461     7.5529
# ...
